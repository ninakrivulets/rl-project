# %%
# !git clone https://github.com/ninakrivulets/rl-project.git
# %cd rl-project
# Out:
# Cloning into 'rl-project'...
# remote: Enumerating objects: 122, done.
# remote: Counting objects: 100% (122/122), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 122 (delta 50), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (122/122), 447.75 KiB | 9.33 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# /kaggle/working/rl-project

# %%
import os
from pathlib import Path

project_root = Path.cwd()

if not (project_root / "main.py").exists():
    project_root = project_root / "paper_nina_arina"

os.chdir(project_root)
print(project_root)
# Out:
# /kaggle/working/rl-project

# %%
# !apt-get update -qq
# !apt-get install -y -qq swig ffmpeg
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Selecting previously unselected package swig4.0.
# (Reading database ... 124626 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !pip install -q -r requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 12.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.1/958.1 kB 36.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.8/315.8 kB 22.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 111.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 116.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 767.5/767.5 kB 49.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 83.1 MB/s eta 0:00:00
# ...

# %%
import os
os.environ["MUJOCO_GL"] = "egl"
os.environ["PYOPENGL_PLATFORM"] = "egl"

# %%
# !python tools/smoke_test.py
# Out:
# name smoke_test
# env id Pendulum-v1
# total_env_steps 1200
# replay_ratio 2
# resets_enabled True
# env: <TimeLimit<OrderEnforcing<PassiveEnvChecker<PendulumEnv<Pendulum-v1>>>>>
# env.observation_space: Box([-1. -1. -8.], [1. 1. 8.], (3,), float32)
# shape: (3,)
# <class 'gymnasium.spaces.box.Box'>
# Box(-2.0, 2.0, (1,), float32)
# smoke_test:  33%|█████████▏                  | 395/1200 [00:06<00:16, 49.14it/s]env: <TimeLimit<OrderEnforcing<PassiveEnvChecker<PendulumEnv<Pendulum-v1>>>>>
# env.observation_space: Box([-1. -1. -8.], [1. 1. 8.], (3,), float32)
# shape: (3,)
# smoke_test:  66%|▋| 797/1200 [00:15<00:08, 50.12it/s, alpha=0.174, best=-1539.6,env: <TimeLimit<OrderEnforcing<PassiveEnvChecker<PendulumEnv<Pendulum-v1>>>>>
# env.observation_space: Box([-1. -1. -8.], [1. 1. 8.], (3,), float32)
# shape: (3,)
# smoke_test: 100%|▉| 1195/1200 [00:23<00:00, 50.11it/s, alpha=0.146, best=-1539.6env: <TimeLimit<OrderEnforcing<PassiveEnvChecker<PendulumEnv<Pendulum-v1>>>>>
# ...

# %% [markdown]
# - env создаётся корректно
# - SAC обучается
# - replay buffer работает
# - reset механизм не ломает обучение
# - видео сохраняется

# %%
# !python main.py --config configs/pendulum_rr32_sac.json
# Out:
# name pendulum_fast_sac
# env id Pendulum-v1
# total_env_steps 30000
# replay_ratio 16
# resets_enabled False
# env: <TimeLimit<OrderEnforcing<PassiveEnvChecker<PendulumEnv<Pendulum-v1>>>>>
# env.observation_space: Box([-1. -1. -8.], [1. 1. 8.], (3,), float32)
# shape: (3,)
# <class 'gymnasium.spaces.box.Box'>
# Box(-2.0, 2.0, (1,), float32)
# pendulum_fast_sac:  17%|██▊              | 4999/30000 [10:43<1:06:13,  6.29it/s]env: <TimeLimit<OrderEnforcing<PassiveEnvChecker<PendulumEnv<Pendulum-v1>>>>>
# env.observation_space: Box([-1. -1. -8.], [1. 1. 8.], (3,), float32)
# shape: (3,)
# pendulum_fast_sac:  33%|▎| 9999/30000 [24:10<53:38,  6.22it/s, alpha=0.191, bestenv: <TimeLimit<OrderEnforcing<PassiveEnvChecker<PendulumEnv<Pendulum-v1>>>>>
# env.observation_space: Box([-1. -1. -8.], [1. 1. 8.], (3,), float32)
# shape: (3,)
# pendulum_fast_sac:  50%|▍| 14999/30000 [37:41<39:43,  6.29it/s, alpha=0.101, besenv: <TimeLimit<OrderEnforcing<PassiveEnvChecker<PendulumEnv<Pendulum-v1>>>>>
# ...

# %%
# !python main.py --config configs/pendulum_rr32_srsac.json
# Out:
# name pendulum_fast_srsac
# env id Pendulum-v1
# total_env_steps 30000
# replay_ratio 16
# resets_enabled True
# env: <TimeLimit<OrderEnforcing<PassiveEnvChecker<PendulumEnv<Pendulum-v1>>>>>
# env.observation_space: Box([-1. -1. -8.], [1. 1. 8.], (3,), float32)
# shape: (3,)
# <class 'gymnasium.spaces.box.Box'>
# Box(-2.0, 2.0, (1,), float32)
# pendulum_fast_srsac:  17%|██▍            | 4999/30000 [10:38<1:07:33,  6.17it/s]env: <TimeLimit<OrderEnforcing<PassiveEnvChecker<PendulumEnv<Pendulum-v1>>>>>
# env.observation_space: Box([-1. -1. -8.], [1. 1. 8.], (3,), float32)
# shape: (3,)
# pendulum_fast_srsac:  33%|▎| 9999/30000 [24:00<52:50,  6.31it/s, alpha=0.191, beenv: <TimeLimit<OrderEnforcing<PassiveEnvChecker<PendulumEnv<Pendulum-v1>>>>>
# env.observation_space: Box([-1. -1. -8.], [1. 1. 8.], (3,), float32)
# shape: (3,)
# pendulum_fast_srsac:  50%|▍| 14999/30000 [37:27<40:39,  6.15it/s, alpha=0.101, benv: <TimeLimit<OrderEnforcing<PassiveEnvChecker<PendulumEnv<Pendulum-v1>>>>>
# ...
